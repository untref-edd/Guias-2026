# %% [markdown]
# # Guía 1.1: Introducción a Python
#
# Esta guía cubre los conceptos fundamentales de Python, estructuras de datos básicas y control de flujo.
# El objetivo es familiarizarse con la sintaxis de Python y sus estructuras idiomáticas.
#
# **Temas:**
# *   Tipos de datos básicos (str, int, float, bool)
# *   Estructuras de datos (list, dict, set, tuple)
# *   Control de flujo (if, for, while)
# *   Funciones básicas

# %% [markdown]
# ### Ejercicio 1: Análisis de Strings
# Implementar la función `contar_vocales(texto)`. Esta función debe recibir una cadena de texto (string) y retornar un diccionario donde las claves sean las vocales (a, e, i, o, u) y los valores sean la cantidad de veces que cada vocal aparece en el texto. La cuenta debe ser insensible a mayúsculas y minúsculas (es decir, 'A' y 'a' se cuentan como la misma vocal). Si una vocal no se encuentra en el texto, su valor en el diccionario debe ser 0.

# %%
def contar_vocales(texto):
    # Tu código aquí
    pass

# %%
# Tests
resultado = contar_vocales("Hola Mundo")
assert resultado.get('a', 0) == 1
assert resultado.get('o', 0) == 2
assert resultado.get('u', 0) == 1
assert resultado.get('e', 0) == 0
assert resultado.get('i', 0) == 0

resultado_complejo = contar_vocales("Murcielago")
assert resultado_complejo['a'] == 1
assert resultado_complejo['e'] == 1
assert resultado_complejo['i'] == 1
assert resultado_complejo['o'] == 1
assert resultado_complejo['u'] == 1

# Cadena vacía
assert contar_vocales("") == {'a': 0, 'e': 0, 'i': 0, 'o': 0, 'u': 0}

# Cadena sin vocales
assert contar_vocales("Rhythm") == {'a': 0, 'e': 0, 'i': 0, 'o': 0, 'u': 0}
assert contar_vocales("bcdfg") == {'a': 0, 'e': 0, 'i': 0, 'o': 0, 'u': 0}

# Cadena con solo vocales (mayúsculas y minúsculas)
resultado_solo_vocales = contar_vocales("AEIOUaeiou")
assert resultado_solo_vocales['a'] == 2
assert resultado_solo_vocales['e'] == 2
assert resultado_solo_vocales['i'] == 2
assert resultado_solo_vocales['o'] == 2
assert resultado_solo_vocales['u'] == 2

# Cadena con caracteres especiales y números
resultado_especiales = contar_vocales("123!@#aEIOU")
assert resultado_especiales['a'] == 1
assert resultado_especiales['e'] == 1
assert resultado_especiales['i'] == 1
assert resultado_especiales['o'] == 1
assert resultado_especiales['u'] == 1

# Cadena con una sola vocal repetida
resultado_solo_a = contar_vocales("AAAAA")
assert resultado_solo_a['a'] == 5
assert resultado_solo_a['e'] == 0
assert resultado_solo_a['i'] == 0
assert resultado_solo_a['o'] == 0
assert resultado_solo_a['u'] == 0

# Ejercicio 1: Tests pasados!
# Out:
# Ejercicio 1: Tests pasados!

# %% [markdown]
# ### Ejercicio 2: Manipulación de Strings
# Implementar la función `es_palindromo(texto)` que verifique si un string es un palíndromo (se lee igual de izquierda a derecha que de derecha a izquierda). Debe ignorar espacios y no distinguir entre mayúsculas y minúsculas.

# %%
def es_palindromo(texto):
    # Tu código aquí
    pass

# %%
# Tests
assert es_palindromo("Neuquen") == True
assert es_palindromo("Anita lava la tina") == True
assert es_palindromo("Hola") == False
assert es_palindromo("") == True

# Ejercicio 2: Tests pasados!

# %% [markdown]
# ### Ejercicio 3: Listas y Bucles
# Implementar la función `filtrar_pares(numeros)` que reciba una lista de enteros y retorne una nueva lista conteniendo solo los números pares.

# %%
def filtrar_pares(numeros):
    # Tu código aquí
    pass

# %%
# Tests
assert filtrar_pares([1, 2, 3, 4, 5, 6]) == [2, 4, 6]
assert filtrar_pares([1, 3, 5]) == []
assert filtrar_pares([2, 4, 6]) == [2, 4, 6]
assert filtrar_pares([]) == []

# Ejercicio 3: Tests pasados!

# %% [markdown]
# ### Ejercicio 4: List Comprehensions
# Implementar `cuadrados_impares(numeros)` que reciba una lista de números y retorne una lista con los cuadrados de los números impares, utilizando **List Comprehensions**.

# %%
def cuadrados_impares(numeros):
    # Tu código aquí
    pass

# %%
# Tests
assert cuadrados_impares([1, 2, 3, 4, 5]) == [1, 9, 25]
assert cuadrados_impares([2, 4, 6]) == []
assert cuadrados_impares([0, 1]) == [1]

# Ejercicio 4: Tests pasados!

# %% [markdown]
# ### Ejercicio 5: Diccionarios
# Implementar `frecuencia_caracteres(texto)` que cuente cuántas veces aparece cada caracter en el texto. La función debe distinguir entre mayúsculas y minúsculas y devolver un diccionario con la frecuencia de cada caracter.

# %%
def frecuencia_caracteres(texto):
    # Tu código aquí
    pass

# %%
# Tests
assert frecuencia_caracteres("banana") == {'b': 1, 'a': 3, 'n': 2}
assert frecuencia_caracteres("aa bb") == {'a': 2, ' ': 1, 'b': 2}
assert frecuencia_caracteres("") == {}
assert frecuencia_caracteres("Hello World!") == {'H': 1, 'e': 1, 'l': 3, 'o': 2, ' ': 1, 'W': 1, 'r': 1, 'd': 1, '!': 1}
assert frecuencia_caracteres("123123") == {'1': 2, '2': 2, '3': 2}

# Ejercicio 5: Tests pasados!

# %% [markdown]
# ### Ejercicio 6: Sets
# Implementar `elementos_comunes(lista1, lista2)` que retorne un `set` con los elementos que aparecen en ambas listas.

# %%
def elementos_comunes(lista1, lista2):
    # Tu código aquí
    pass

# %%
# Tests
assert elementos_comunes([1, 2, 3], [3, 4, 5]) == {3}
assert elementos_comunes([1, 2], [3, 4]) == set()
assert elementos_comunes([1, 1, 2], [1, 2, 2]) == {1, 2}

# Ejercicio 6: Tests pasados!

# %% [markdown]
# ### Ejercicio 7: Tuplas
# Implementar `min_max_tupla(numeros)` que reciba una lista de números y retorne una tupla `(minimo, maximo)`. Si la tupla está vacía debe retornar una tupla con dos valores `None`.

# %%
def min_max_tupla(numeros):
    # Tu código aquí
    pass

# %%
# Tests
assert min_max_tupla([1, 5, 2, 8, 3]) == (1, 8)
assert min_max_tupla([5]) == (5, 5)
assert min_max_tupla([]) == (None, None)

# Ejercicio 7: Tests pasados!

# %% [markdown]
# ### Ejercicio 8: Año Bisiesto
# Implementar `es_bisiesto(anio)` que retorne `True` si el año es bisiesto y `False` en caso contrario.
# Regla: Un año es bisiesto si es divisible por 4, excepto si es divisible por 100, en cuyo caso debe ser divisible por 400.

# %%
def es_bisiesto(anio):
    # Tu código aquí
    pass

# %%
assert es_bisiesto(1900) == False
assert es_bisiesto(2026) == False
assert es_bisiesto(2027) == False
assert es_bisiesto(2028) == True
assert es_bisiesto(2029) == False
assert es_bisiesto(2030) == False
assert es_bisiesto(2031) == False
assert es_bisiesto(2032) == True
assert es_bisiesto(2033) == False
assert es_bisiesto(2034) == False
assert es_bisiesto(2035) == False
assert es_bisiesto(2036) == True
assert es_bisiesto(2037) == False
assert es_bisiesto(2038) == False
assert es_bisiesto(2039) == False
assert es_bisiesto(2040) == True
assert es_bisiesto(2100) == False




# Ejercicio 8: Tests pasados!

# %% [markdown]
# ### Ejercicio 9: Bucles (While/For)
# Implementar `factorial(n)` que calcule el factorial de un número de manera iterativa (no recursiva). Usar técnicas de programación dinámica para optimizar el cálculo.

# %%
def factorial(n):
    # Tu código aquí
    pass

# %%
# Tests
assert factorial(0) == 1
assert factorial(1) == 1
assert factorial(5) == 120
assert factorial(100) == 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# Ejercicio 9: Tests pasados!
# Out:
# Ejercicio 9: Tests pasados!

# %% [markdown]
# ### Ejercicio 10: Funciones con *args
# Implementar `calculadora_basica(operacion, *args)` que realice una operación ('suma', 'resta', 'multiplicacion') sobre todos los argumentos pasados.
# *   'suma': sumar todos
# *   'resta': restar al primero el resto
# *   'multiplicacion': multiplicar todos

# %%
def calculadora_basica(operacion, *args):
    # Tu código aquí
    pass

# %%
# Tests
assert calculadora_basica('suma', 1, 2, 3) == 6
assert calculadora_basica('resta', 10, 2, 3) == 5
assert calculadora_basica('multiplicacion', 2, 3, 4) == 24

# Ejercicio 10: Tests pasados!

# %% [markdown]
# ### Ejercicio 11: Funciones con **kwargs
# Implementar `formatear_saludo(mensaje, **kwargs)` que tome un mensaje base con placeholders (ej: "Hola {nombre}") y reemplace los valores usando los argumentos nombrados.

# %%
def formatear_saludo(mensaje, **kwargs):
    # Tu código aquí
    # Ayuda: usar string.format(**kwargs)
    pass

# %%
# Tests
assert formatear_saludo("Hola {nombre}", nombre="Juan") == "Hola Juan"
assert formatear_saludo("{a} + {b} = {c}", a=1, b=2, c=3) == "1 + 2 = 3"

# Ejercicio 11: Tests pasados!

# %% [markdown]
# ### Ejercicio 12: Validación de Contraseña
# Implementar `validar_contrasena(password)` que verifique si una contraseña es válida.
# Reglas:
# *   Longitud mayor a 8
# *   Debe contener al menos un numero
# *   Debe contener al menos una mayúscula

# %%
def validar_contrasena(password):
    # Tu código aquí
    pass

# %%
# Tests
assert validar_contrasena("Password123") == True
assert validar_contrasena("password123") == False # Faltan mayusculas
assert validar_contrasena("Pass") == False # Muy corta
assert validar_contrasena("Password") == False # Falta numero

# Ejercicio 12: Tests pasados!

# %% [markdown]
# ### Ejercicio 13: Mergesort
# Implementar el algoritmo de ordenamiento `mergesort(lista)` utilizando la técnica de **Divide y Vencerás**. La función debe retornar una nueva lista ordenada.

# %%
def mergesort(lista):
    # Tu código aquí
    pass

# %%
# Tests
assert mergesort([3, 1, 4, 1, 5, 9, 2, 6, 5]) == [1, 1, 2, 3, 4, 5, 5, 6, 9]
assert mergesort([]) == []
assert mergesort([1]) == [1]
assert mergesort([2, 1]) == [1, 2]
assert mergesort([1, 2, 3]) == [1, 2, 3]
assert mergesort([3, 2, 1]) == [1, 2, 3]

# Ejercicio 13: Tests pasados!

# %% [markdown]
# ### Ejercicio 14: Búsqueda Binaria Recursiva
# Implementar la función `busqueda_binaria_recursiva(lista, objetivo, izquierda, derecha)` que busque un elemento en una lista **ordenada** de forma recursiva. Debe retornar el índice del elemento si se encuentra, o `-1` si no está.

# %%
def busqueda_binaria_recursiva(lista, objetivo, izquierda, derecha):
    # Tu código aquí
    pass

# %%
# Tests
lista_ordenada = [1, 2, 3, 4, 5, 6, 7, 8, 9]
assert busqueda_binaria_recursiva(lista_ordenada, 5, 0, len(lista_ordenada) - 1) == 4
assert busqueda_binaria_recursiva(lista_ordenada, 1, 0, len(lista_ordenada) - 1) == 0
assert busqueda_binaria_recursiva(lista_ordenada, 9, 0, len(lista_ordenada) - 1) == 8
assert busqueda_binaria_recursiva(lista_ordenada, 10, 0, len(lista_ordenada) - 1) == -1
assert busqueda_binaria_recursiva([], 5, 0, -1) == -1

# Ejercicio 14: Tests pasados!
